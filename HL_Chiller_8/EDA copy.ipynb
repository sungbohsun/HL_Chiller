# %%
import numpy as np
import plotly.graph_objects as go
from datetime import timedelta
from utils.DataProcess import Start
df = Start('HL_14')

# %%
from plotly.graph_objs.layout import YAxis,XAxis,Margin
layout = go.Layout(
    # title="{}".format(self.df_last.Datetime),
    yaxis=YAxis(
        title="<b> system KPI</b>"
    ),
    yaxis2 = YAxis(
        title="<b> Wet bulb temp </b>",
        overlaying= 'y', 
        side= 'right',
    ),
    xaxis=dict(
        title="<b> Cost (Kw)</b>"
    ),
)
fig =  go.Figure(layout=layout)
fig.add_trace(
    go.Scatter(
        x = df.Datetime,
        y = df.system_KPI,
        name = 'system KPI',
        mode='lines',
        yaxis='y2'
    ))
fig.add_trace(
    go.Scatter(
        x = df.Datetime,
        y = df.Wet_bulb_temp,
        mode='lines',
        name = 'Wet bulb temp',
        yaxis='y1'
        
    ))

WB = df.Wet_bulb_temp.iloc[-100]

xs = df[df.Wet_bulb_temp==WB].Datetime
for x in xs:
    fig.add_vrect(
        x0=x - timedelta(minutes=15),
        x1=x + timedelta(minutes=15),
        fillcolor="Green",
        opacity=0.5,
        line_width=0,
    )

fig.add_hline(y=df.Wet_bulb_temp.iloc[-1])

# %%
Ms,Ai,count = [],[],[]


for WB in np.linspace(40,80,40):

    before = df[df.Datetime < '2022/10/28']
    before.Enthalpy = round(before.Enthalpy,2)
    Ms.append(np.median(before[before.Enthalpy==round(WB,2)].system_KPI))

    after = df[df.Datetime >= '2022/10/29']
    after.Enthalpy = round(after.Enthalpy,2)
    ahter_rh = after[after.Enthalpy==round(WB,2)]
    Ai.append(np.median(ahter_rh.system_KPI))
    count.append(ahter_rh.shape[0])
# Out:
# C:\Users\ZME\AppData\Local\Temp\ipykernel_4744\4002336285.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ZME\AppData\Local\Temp\ipykernel_4744\4002336285.py:11: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
layout = go.Layout(
    # title="{}".format(self.df_last.Datetime),
    yaxis=YAxis(
        title="<b> system KPI</b>"
    ),
    xaxis=dict(
        title="<b> Enthalpy </b>"
    ),
)
fig =  go.Figure(layout=layout)
fig.add_trace(
    go.Scatter(
        x = before.Enthalpy,
        y = before.system_KPI,
        name = 'before',
        mode='markers',
        opacity=0.7,
        marker=dict(
            color='LightSkyBlue',
            size=3)
    ))
fig.add_trace(
    go.Scatter(
        x = after.Enthalpy,
        y = after.system_KPI,
        mode='markers',
        opacity=0.7,
        marker=dict(
            # color='LightSkyBlue',
            size=3),
        name = 'AI',
        
    ))

# %%
Ms,Ai,Max,Min = [],[],[],[]


for WB in np.linspace(40,80,40):

    before = df[df.Datetime < '2022/10/28']
    before.Enthalpy = round(before.Enthalpy,1)
    Ms.append(np.median(before[before.Enthalpy==round(WB,1)].system_KPI))
    Max.append(before[before.Enthalpy==round(WB,1)].system_KPI.max())
    Min.append(before[before.Enthalpy==round(WB,1)].system_KPI.min())

    after = df[df.Datetime >= '2022/10/29']
    after.Enthalpy = round(after.Enthalpy,1)
    ahter_rh = after[after.Enthalpy==round(WB,1)]
    Ai.append(np.median(ahter_rh.system_KPI))
    count.append(ahter_rh.shape[0])

layout = go.Layout(
    # title="{}".format(self.df_last.Datetime),
    yaxis=YAxis(
        title="<b> system KPI</b>"
    ),
    xaxis=dict(
        title="<b>Enthalpy</b>"
    ),
)
fig =  go.Figure(layout=layout)
fig.add_trace(
    go.Scatter(
        x = np.linspace(40,80,40),
        y = Ms,
        name = 'before Mean',
        # mode='markers',
        opacity=0.7,
        marker=dict(
            # color='LightSkyBlue',
            size=3),
        line = dict(
            # color='royalblue', 
            width=4, 
            # dash='dash'
            )
    ))

fig.add_trace(
    go.Scatter(
        x = np.linspace(40,80,40),
        y = Max,
        name = 'before Max',
        # mode='markers',
        opacity=0.7,
        marker=dict(
            # color='LightSkyBlue',
            size=3),
        line = dict(
            # color='royalblue', 
            # width=4, 
            dash='dash')
    ))


fig.add_trace(
    go.Scatter(
        x = np.linspace(40,80,40),
        y = Min,
        name = 'before Min',
        # mode='markers',
        opacity=0.7,
        marker=dict(
            # color='LightSkyBlue',
            size=3),
        line = dict(
            # color='royalblue', 
            # width=4, 
            dash='dash')
    ))

fig.add_trace(go.Scatter(
     x = np.linspace(40,80,40),
     y = Max,
    fill='tonexty',
    fillcolor='rgba(184, 247, 212,0.2)',
    line_color='rgba(255,255,255,0)',
    showlegend=False,
    name='Ideal',
))

fig.add_trace(
    go.Scatter(
        x = after.Enthalpy,
        y = after.system_KPI,
        mode='markers',
        opacity=1,
        marker=dict(
            color='red',
            size=3),
        # line = dict(
        #     # color='royalblue', 
        #     width=4, 
        #     # dash='dash'
        #     ),
            
        name = 'AI control',
        
    ))
# Out:
# C:\Users\ZME\AppData\Local\Temp\ipykernel_4744\500421263.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ZME\AppData\Local\Temp\ipykernel_4744\500421263.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
##training
import os,pickle
import pandas as pd
from utils.DataProcess import Start
from utils.ClooingTowerOptimize import CT_opt

# opt = CT_opt()
# opt.df = Start('HL_14')

# opt.train()
# with open(os.path.join('model','regr.pkl'), 'wb') as f:
#     pickle.dump(opt, f)

# %%
df = pd.read_csv(os.path.join('input','small_df.csv'))
df1 = df.iloc[-50:]
df1.index = df1.Datetime
df1[[f'CH_{c}_sug_temp' for c in range(1,10)]]
# Out:
#                     CH_1_sug_temp CH_2_sug_temp CH_3_sug_temp CH_4_sug_temp  \
# Datetime
# 2022-10-26 09:20:00             0            13             0             0
# 2022-10-26 09:30:00           NaN           NaN           NaN           NaN
# 2022-10-26 09:40:00           NaN           NaN           NaN           NaN
# 2022-10-26 09:50:00             0            13             0             0
# 2022-10-26 10:00:00           NaN           NaN           NaN           NaN
# 2022-10-26 10:10:00           NaN           NaN           NaN           NaN
# 2022-10-26 10:20:00             0            13             0             0
# 2022-10-26 10:30:00           NaN           NaN           NaN           NaN
# 2022-10-26 10:40:00           NaN           NaN           NaN           NaN
# 2022-10-26 10:50:00         @10.1         @10.1         @10.1         @10.1
# 2022-10-26 11:00:00           NaN           NaN           NaN           NaN
# ...

# %%
df = pd.read_csv(os.path.join('input','small_df.csv'))
df1 = df.iloc[-1]
res = {}
res['Dtime'] = pd.to_datetime(df1.Datetime)
res['CH_low'] = 13.5
res['CH_high'] = 15.0
res['select'] = []
res['AI_supply_temp'] = 14.0
res['CT_low'] = 21.5
res['CT_high'] = 26.0
res['best_CT'] = 23.0
with open(os.path.join('config','setting.pkl'), 'wb') as f:
    pickle.dump(res, f)

# %%
res['Dtime'] = pd.to_datetime(df1.Datetime)
res['CH_low'] = 13.5
res['CH_high'] = 15
res['select'] = []
res['AI_supply_temp'] = 14
res['CT_low'] = 21.5
res['CT_high'] = 26
res['best_CT'] = 23
with open(os.path.join('config','setting.pkl'), 'wb') as f:
    pickle.dump(res, f)

# %%
with open(os.path.join('config','setting.pkl'), 'rb') as f:
    res = pickle.load(f)

# %%
opt.df.CH14_Tune
# Out:
# 79        NaN
# 80        NaN
# 81        NaN
# 82        NaN
# 83        NaN
#         ...
# 4394      NaN
# 4395      NaN
# 4396      NaN
# 4397    14.16
# 4398      NaN
# Name: CH14_Tune, Length: 4320, dtype: float64

# %%
list(opt.df.columns)
# Out:
# ['Unnamed: 0',
#  'ID',
#  'Datetime',
#  'OA_TT1',
#  'OA_MT1',
#  'Enthalpy',
#  'OA_TT2',
#  'OA_MT2',
#  'OA_E2',
#  'CT_WDT',
#  'chiller_kwh',
#  'CH14_KPI',
#  'chiller_flow',
#  'CH14_CWP_FT',
#  'chiller_supply_temp',
#  'chiller_return_temp',
#  'condenser_supply_temp',
#  'condenser_return_temp',
#  'CT_01_VFD',
#  'CT_03_VFD',
#  'CT_05_VFD',
#  'CT_07_VFD',
#  'CT_09_VFD',
#  'CT_11_VFD',
#  'CT_13_VFD',
#  'CT_Total_KW',
#  'RAC_10_127_Output',
#  'RAC_10_130_Output',
#  'RAC_10_131_Output',
#  'RAC_10_132_Output',
#  'RAC_10_133_Output',
#  'RAC_10_134_Output',
#  'RAC_10_135_Output',
#  'RAC_10_136_Output',
#  'RAC_10_137_Output',
#  'RAC_L20_Output',
#  'L35_CR_Z01_Output',
#  'L35_CR_Z02_Output',
#  'L35_CR_Z03_Output',
#  'L35_CR_Z04_Output',
#  'L35_CR_Z05_Output',
#  'L35_CR_Z06_Output',
#  'L35_CR_Z07_Output',
#  'L35_CR_Z08_Output',
#  'L35_CR_Z09_Output',
#  'L35_CR_Z10_Output',
#  'L35_CR_Z11_Output',
#  'L35_CR_Z12_Output',
#  'L35_CR_Z13_Output',
# ...

# %%
ch = opt.df[[f'CH_{c}_sug_temp' for c in range(1,10)]].astype(float).dropna()

# %%
ch.iloc[-1010:-1000]
# Out:
#       CH_1_sug_temp  CH_2_sug_temp  CH_3_sug_temp  CH_4_sug_temp  \
# 1357            0.0           13.0            0.0            0.0
# 1360            0.0           13.0            0.0            0.0
# 1363            0.0           13.0            0.0            0.0
# 1366            0.0           13.0            0.0            0.0
# 1369            0.0           13.0            0.0            0.0
# 1372            0.0           13.0            0.0            0.0
# 1375            0.0           13.0            0.0            0.0
# 1378            0.0           13.0            0.0            0.0
# 1381            0.0           13.0            0.0            0.0
# 1384            0.0           13.0            0.0            0.0
#
#       CH_5_sug_temp  CH_6_sug_temp  CH_7_sug_temp  CH_8_sug_temp  \
# 1357           14.5           13.0           14.5          13.08
# 1360           14.5           13.0           14.5          13.08
# ...

# %%
ch.iloc[-10:]
# Out:
#       CH_1_sug_temp  CH_2_sug_temp  CH_3_sug_temp  CH_4_sug_temp  \
# 4357            0.0           13.0            0.0            0.0
# 4360            0.0           13.0            0.0            0.0
# 4363            0.0           13.0            0.0            0.0
# 4366            0.0           13.0            0.0            0.0
# 4369            0.0           13.0            0.0            0.0
# 4372            0.0           13.0            0.0            0.0
# 4375            0.0           13.0            0.0            0.0
# 4378            0.0           13.0            0.0            0.0
# 4381            0.0           13.0            0.0            0.0
# 4384            0.0           13.0            0.0            0.0
#
#       CH_5_sug_temp  CH_6_sug_temp  CH_7_sug_temp  CH_8_sug_temp  \
# 4357           14.5           13.0           14.5          13.08
# 4360           14.5           13.0           14.5          13.08
# ...

# %%
ch.plot()

# %%
# eval plot
import os,pickle
import numpy as np
import plotly.graph_objects as go
from tqdm import tqdm
from utils.DataProcess import Start
from utils.ClooingTowerOptimize import CT_opt
with open(os.path.join('model','regr.pkl'), 'rb') as p:
    opt = pickle.load(p)


vs = []
for c in tqdm(range(1000)):
    try:
        opt.predict(c)
        v,fig = opt.plot(21,29)
        vs.append(v)
    except:
        pass


fig = go.Figure()
fig.add_traces(go.Scatter(x=opt.df.Datetime[-1000:][::-1],y=opt.df.condenser_supply_temp[-1000:][::-1],mode='lines',name='Manual'))
fig.add_traces(go.Scatter(x=opt.df.Datetime[-1000:][::-1],y=np.array(vs),mode='lines',name='AI'))
fig.add_traces(go.Scatter(x=opt.df.Datetime[-1000:][::-1],y=opt.df.Wet_bulb_temp[-1000:][::-1],mode='lines',name='Wet bulb'))
# Out:
# 100%|██████████| 1000/1000 [00:19<00:00, 50.16it/s]

# %%
import pickle,os,time
import pandas as pd
from datetime import datetime
from dateutil.relativedelta import relativedelta
from utils.SQL import SQL
from utils.DataProcess import Start
from utils.ClooingTowerOptimize import CT_opt

#loadong data from DB
sql = SQL(server = "L8BAVMSQL\SQLEXPRESS",
            database = "HL_Chiller",
            username = "vefaa2",
            password = "Aa123456")

data = sql.get_data(datatabel = "Optimize",
                    StartDate = "{}".format((datetime.now() + relativedelta(months=-1)).strftime("%Y-%m-%d")),
                    ReturnFormat = "DataFrame")

# %%
data.index=data.Date
data[['CH_9_sug_temp','CT_sug_temp']].iloc[-10:]
# Out:
#                     CH_9_sug_temp CT_sug_temp
# Date
# 2022-10-28 12:40:00         13.92       22.51
# 2022-10-28 12:50:00         13.94       22.73
# 2022-10-28 13:00:00         13.95       22.54
# 2022-10-28 13:10:00         13.95       22.59
# 2022-10-28 13:20:00         13.75       22.35
# 2022-10-28 13:30:00         13.73       22.54
# 2022-10-28 13:40:00         13.71       22.61
# 2022-10-28 13:50:00         13.62       22.48
# 2022-10-28 14:00:00        @13.54      @22.43
# 2022-10-28 14:10:00          None        None
